# %% [markdown]
# ## Churn Case - Part 1

# %%
# importing necessary libraries

import pandas as pd
import sqlite3

# %% [markdown]
# ### Reading all CSV files with Pandas

# %%
customer = pd.read_csv("customer.csv")
customer.head()
# Out:
#    CustomerID  Gender SeniorCitizen Partner Dependents
# 0  3668-QPYBK    Male            No      No         No
# 1  9237-HQITU  Female            No      No        Yes
# 2  9305-CDSKC  Female            No      No        Yes
# 3  7892-POOKP  Female            No     Yes        Yes
# 4  0280-XJGEX    Male            No      No        Yes

# %%
cust_loc = pd.read_csv("cust_loc.csv")
cust_loc.head()
# Out:
#       Cust_ID       State   Latitude   Longitude  ZipCode
# 0  3668-QPYBK  California  33.964131 -118.272783    90003
# 1  9237-HQITU  California  34.059281 -118.307420    90005
# 2  9305-CDSKC  California  34.048013 -118.293953    90006
# 3  7892-POOKP  California  34.062125 -118.315709    90010
# 4  0280-XJGEX  California  34.039224 -118.266293    90015

# %%
cust_services = pd.read_csv("cust_services.csv")
cust_services.head()
# Out:
#       Cust_ID PhoneService MultipleLines InternetService OnlineSecurity  \
# 0  3668-QPYBK          Yes            No             DSL            Yes
# 1  9237-HQITU          Yes            No     Fiber optic             No
# 2  9305-CDSKC          Yes           Yes     Fiber optic             No
# 3  7892-POOKP          Yes           Yes     Fiber optic             No
# 4  0280-XJGEX          Yes           Yes     Fiber optic             No
#
#   OnlineBackup DeviceProtection TechSupport StreamingTV StreamingMovies
# 0          Yes               No          No          No              No
# 1           No               No          No          No              No
# 2           No              Yes          No         Yes             Yes
# 3           No              Yes         Yes         Yes             Yes
# 4          Yes              Yes          No         Yes             Yes

# %%
cust_account = pd.read_csv("cust_account.csv")
cust_account.head()
# Out:
#    Account_id  Tenure        Contract              PaymentMethod  \
# 0  3668-QPYBK       2  Month-to-month               Mailed check
# 1  9237-HQITU       2  Month-to-month           Electronic check
# 2  9305-CDSKC       8  Month-to-month           Electronic check
# 3  7892-POOKP      28  Month-to-month           Electronic check
# 4  0280-XJGEX      49  Month-to-month  Bank transfer (automatic)
#
#   PaperlessBilling  MonthlyCharges TotalCharges
# 0              Yes           53.85       108.15
# 1              Yes           70.70       151.65
# 2              Yes           99.65        820.5
# 3              Yes          104.80      3046.05
# 4              Yes          103.70       5036.3

# %%
cust_churn = pd.read_csv("cust_churn.csv")
cust_churn.head()
# Out:
#            Id Churn
# 0  3668-QPYBK   Yes
# 1  9237-HQITU   Yes
# 2  9305-CDSKC   Yes
# 3  7892-POOKP   Yes
# 4  0280-XJGEX   Yes

# %% [markdown]
# ## Create database and tables

# %%
conn = sqlite3.connect("churn.db")
cur = conn.cursor()

# %%
# create the customer table

customer.to_sql("customer", conn, if_exists = "replace", index = False)
# Out:
# 7043

# %%
#create the customer location table

cust_loc.to_sql("cust_loc", conn, if_exists = "replace", index = False)
# Out:
# 7043

# %%
# create customer services table

cust_services.to_sql("cust_services", conn, if_exists = "replace", index = False)
# Out:
# 7043

# %%
# create customer account table

cust_account.to_sql("cust_account", conn, if_exists = "replace", index = False)
# Out:
# 7043

# %%
#create customer churn table

cust_churn.to_sql("cust_churn", conn, if_exists = "replace", index = False)
# Out:
# 7043

# %% [markdown]
# ## Information about our tables

# %%
def table_info(conn,cursor):
    """
    prints out all the coulumns of every table in th DB
    
    conn: database connection object
    cursor: cursor object
    """
    tables = cur.execute("SELECT name FROM sqlite_master WHERE type='table';").fetchall()
    for table_name in tables:
        table_name = table_name[0]
        table = pd.read_sql_query("SELECT * from {} LIMIT 0".format(table_name), conn)
        print(table_name)
        for col in table.columns:
            print("\t "+ col)
            print()

# %%
table_info(conn,cur)
# Out:
# customer
# 	 CustomerID
#
# 	 Gender
#
# 	 SeniorCitizen
#
# 	 Partner
#
# 	 Dependents
#
# cust_loc
# 	 Cust_ID
#
# 	 State
#
# 	 Latitude
#
# 	 Longitude
#
# 	 ZipCode
#
# cust_services
# 	 Cust_ID
#
# 	 PhoneService
#
# 	 MultipleLines
#
# 	 InternetService
#
# 	 OnlineSecurity
#
# 	 OnlineBackup
#
# 	 DeviceProtection
#
# 	 TechSupport
#
# 	 StreamingTV
#
# 	 StreamingMovies
#
# cust_account
# 	 Account_id
#
# 	 Tenure
#
# 	 Contract
#
# 	 PaymentMethod
#
# 	 PaperlessBilling
#
# 	 MonthlyCharges
#
# 	 TotalCharges
#
# cust_churn
# 	 Id
#
# 	 Churn

# %% [markdown]
# ## Join all tables

# %%
cur.execute(
"""
ALTER TABLE cust_loc
RENAME COLUMN Cust_ID TO CustomerID
""")

# %%
table_info(conn,cur)
# Out:
# customer
# 	 CustomerID
#
# 	 Gender
#
# 	 SeniorCitizen
#
# 	 Partner
#
# 	 Dependents
#
# cust_loc
# 	 CustomerID
#
# 	 State
#
# 	 Latitude
#
# 	 Longitude
#
# 	 ZipCode
#
# cust_services
# 	 Cust_ID
#
# 	 PhoneService
#
# 	 MultipleLines
#
# 	 InternetService
#
# 	 OnlineSecurity
#
# 	 OnlineBackup
#
# 	 DeviceProtection
#
# 	 TechSupport
#
# 	 StreamingTV
#
# 	 StreamingMovies
#
# cust_account
# 	 Account_id
#
# 	 Tenure
#
# 	 Contract
#
# 	 PaymentMethod
#
# 	 PaperlessBilling
#
# 	 MonthlyCharges
#
# 	 TotalCharges
#
# cust_churn
# 	 Id
#
# 	 Churn

# %%
cur.execute(
"""
SELECT
*
FROM customer
INNER JOIN cust_loc
USING (CustomerID)
""")
cur.fetchone()
# Out:
# ('3668-QPYBK',
#  'Male',
#  'No',
#  'No',
#  'No',
#  'California',
#  33.964131,
#  -118.272783,
#  90003)

# %%
cust_loc = cust_loc.rename(columns={"Cust_ID": "CustomerID"})

# %%
cust_loc.head()
# Out:
#    CustomerID       State   Latitude   Longitude  ZipCode
# 0  3668-QPYBK  California  33.964131 -118.272783    90003
# 1  9237-HQITU  California  34.059281 -118.307420    90005
# 2  9305-CDSKC  California  34.048013 -118.293953    90006
# 3  7892-POOKP  California  34.062125 -118.315709    90010
# 4  0280-XJGEX  California  34.039224 -118.266293    90015

# %%
pd.concat([customer, cust_loc], join='inner', axis=1)
# Out:
#       CustomerID  Gender SeniorCitizen Partner Dependents  CustomerID  \
# 0     3668-QPYBK    Male            No      No         No  3668-QPYBK
# 1     9237-HQITU  Female            No      No        Yes  9237-HQITU
# 2     9305-CDSKC  Female            No      No        Yes  9305-CDSKC
# 3     7892-POOKP  Female            No     Yes        Yes  7892-POOKP
# 4     0280-XJGEX    Male            No      No        Yes  0280-XJGEX
# ...          ...     ...           ...     ...        ...         ...
# 7038  2569-WGERO  Female            No      No         No  2569-WGERO
# 7039  6840-RESVB    Male            No     Yes        Yes  6840-RESVB
# 7040  2234-XADUH  Female            No     Yes        Yes  2234-XADUH
# 7041  4801-JZAZL  Female            No     Yes        Yes  4801-JZAZL
# 7042  3186-AJIEK    Male            No      No         No  3186-AJIEK
#
#            State   Latitude   Longitude  ZipCode
# 0     California  33.964131 -118.272783    90003
# 1     California  34.059281 -118.307420    90005
# 2     California  34.048013 -118.293953    90006
# 3     California  34.062125 -118.315709    90010
# 4     California  34.039224 -118.266293    90015
# ...          ...        ...         ...      ...
# 7038  California  34.341737 -116.539416    92285
# 7039  California  34.667815 -117.536183    92301
# 7040  California  34.559882 -115.637164    92304
# 7041  California  34.167800 -116.864330    92305
# 7042  California  34.424926 -117.184503    92308
#
# [7043 rows x 10 columns]

# %%
# rename remaining columns from table

cust_services = cust_services.rename(columns={"Cust_ID": "CustomerID"})
cust_account = cust_account.rename(columns={"Account_id": "CustomerID"})
cust_churn = cust_churn.rename(columns={"Id": "CustomerID"})

# %%
dfs_to_join = [customer,cust_loc, cust_services, cust_account, cust_churn]

# %%
churn_all = pd.concat(dfs_to_join, join='inner', axis=1)

# %%
churn_all.head()
# Out:
#    CustomerID  Gender SeniorCitizen Partner Dependents  CustomerID  \
# 0  3668-QPYBK    Male            No      No         No  3668-QPYBK
# 1  9237-HQITU  Female            No      No        Yes  9237-HQITU
# 2  9305-CDSKC  Female            No      No        Yes  9305-CDSKC
# 3  7892-POOKP  Female            No     Yes        Yes  7892-POOKP
# 4  0280-XJGEX    Male            No      No        Yes  0280-XJGEX
#
#         State   Latitude   Longitude  ZipCode  ... StreamingMovies  \
# 0  California  33.964131 -118.272783    90003  ...              No
# 1  California  34.059281 -118.307420    90005  ...              No
# 2  California  34.048013 -118.293953    90006  ...             Yes
# 3  California  34.062125 -118.315709    90010  ...             Yes
# 4  California  34.039224 -118.266293    90015  ...             Yes
#
#    CustomerID Tenure        Contract              PaymentMethod  \
# 0  3668-QPYBK      2  Month-to-month               Mailed check
# 1  9237-HQITU      2  Month-to-month           Electronic check
# 2  9305-CDSKC      8  Month-to-month           Electronic check
# 3  7892-POOKP     28  Month-to-month           Electronic check
# 4  0280-XJGEX     49  Month-to-month  Bank transfer (automatic)
#
#   PaperlessBilling MonthlyCharges TotalCharges  CustomerID Churn
# 0              Yes          53.85       108.15  3668-QPYBK   Yes
# 1              Yes          70.70       151.65  9237-HQITU   Yes
# 2              Yes          99.65        820.5  9305-CDSKC   Yes
# 3              Yes         104.80      3046.05  7892-POOKP   Yes
# 4              Yes         103.70       5036.3  0280-XJGEX   Yes
#
# [5 rows x 29 columns]

# %%
~churn_all.columns.duplicated()
# Out:
# array([ True,  True,  True,  True,  True, False,  True,  True,  True,
#         True, False,  True,  True,  True,  True,  True,  True,  True,
#         True,  True, False,  True,  True,  True,  True,  True,  True,
#        False,  True])

# %%
churn_all = churn_all.loc[:, ~churn_all.columns.duplicated()]

# %%
churn_all.head()
# Out:
#    CustomerID  Gender SeniorCitizen Partner Dependents       State   Latitude  \
# 0  3668-QPYBK    Male            No      No         No  California  33.964131
# 1  9237-HQITU  Female            No      No        Yes  California  34.059281
# 2  9305-CDSKC  Female            No      No        Yes  California  34.048013
# 3  7892-POOKP  Female            No     Yes        Yes  California  34.062125
# 4  0280-XJGEX    Male            No      No        Yes  California  34.039224
#
#     Longitude  ZipCode PhoneService  ... TechSupport StreamingTV  \
# 0 -118.272783    90003          Yes  ...          No          No
# 1 -118.307420    90005          Yes  ...          No          No
# 2 -118.293953    90006          Yes  ...          No         Yes
# 3 -118.315709    90010          Yes  ...         Yes         Yes
# 4 -118.266293    90015          Yes  ...          No         Yes
#
#   StreamingMovies Tenure        Contract              PaymentMethod  \
# 0              No      2  Month-to-month               Mailed check
# 1              No      2  Month-to-month           Electronic check
# 2             Yes      8  Month-to-month           Electronic check
# 3             Yes     28  Month-to-month           Electronic check
# 4             Yes     49  Month-to-month  Bank transfer (automatic)
#
#   PaperlessBilling MonthlyCharges  TotalCharges Churn
# 0              Yes          53.85        108.15   Yes
# 1              Yes          70.70        151.65   Yes
# 2              Yes          99.65         820.5   Yes
# 3              Yes         104.80       3046.05   Yes
# 4              Yes         103.70        5036.3   Yes
#
# [5 rows x 25 columns]

# %%
~churn_all.columns.duplicated()
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True])

# %%
churn_all.to_csv('churn_all.csv')

# %%
churn_all.to_sql('churn_all', conn, index=False, if_exists='replace')
# Out:
# 7043

# %%
conn.commit()

# %%
df = pd.read_sql("SELECT * FROM churn_all", conn)

# %%
cursor = conn.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(cursor.fetchall())
# Out:
# [('customer',), ('cust_loc',), ('cust_services',), ('cust_account',), ('cust_churn',), ('churn_all',)]

# %%
table_info(conn,cur)
# Out:
# customer
# 	 CustomerID
#
# 	 Gender
#
# 	 SeniorCitizen
#
# 	 Partner
#
# 	 Dependents
#
# cust_loc
# 	 CustomerID
#
# 	 State
#
# 	 Latitude
#
# 	 Longitude
#
# 	 ZipCode
#
# cust_services
# 	 Cust_ID
#
# 	 PhoneService
#
# 	 MultipleLines
#
# 	 InternetService
#
# 	 OnlineSecurity
#
# 	 OnlineBackup
#
# 	 DeviceProtection
#
# 	 TechSupport
#
# 	 StreamingTV
#
# 	 StreamingMovies
#
# cust_account
# 	 Account_id
#
# 	 Tenure
#
# 	 Contract
#
# 	 PaymentMethod
#
# 	 PaperlessBilling
#
# 	 MonthlyCharges
#
# 	 TotalCharges
#
# cust_churn
# 	 Id
#
# 	 Churn
#
# churn_all
# 	 CustomerID
#
# 	 Gender
#
# 	 SeniorCitizen
#
# 	 Partner
#
# 	 Dependents
#
# 	 State
#
# 	 Latitude
#
# 	 Longitude
#
# 	 ZipCode
#
# 	 PhoneService
#
# 	 MultipleLines
#
# 	 InternetService
#
# 	 OnlineSecurity
#
# 	 OnlineBackup
#
# 	 DeviceProtection
#
# 	 TechSupport
#
# 	 StreamingTV
#
# 	 StreamingMovies
#
# 	 Tenure
#
# 	 Contract
#
# 	 PaymentMethod
#
# 	 PaperlessBilling
#
# 	 MonthlyCharges
#
# 	 TotalCharges
#
# 	 Churn
